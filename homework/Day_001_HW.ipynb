# %% [markdown]
# # 作業1：
#
# #### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Jigsaw Unintended Bias in Toxicity Classification
#
# 1. 你選的這組資料為何重要
#
# 社群網路發達的現代社會中，人們在網路暢所欲言，但因可隱藏身分的特性，容易克制不住留下較為負面的言論，舉凡人身攻擊、猥褻、威脅、侮辱、色情等。若能在第一時間發現這些負面言論予以刪除，可讓社群環境更為正向，因此如何辨識負面言論就成為重要的課題。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 來自Civil Comments，以插件的形式使用在獨立新聞網站上，透過眾包方式從大量的網路使用者蒐集資訊。
#
# 3. 蒐集而來的資料型態為何
#
# 留言評論的字串與對應的毒性數值(0~1)。
#
# 4. 這組資料想解決的問題如何評估
#
# 分類，若判斷毒性數值>=0.5則分類為有毒的。
#
#
# # 作業2：
#
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 首先需要定義業績如何計算，可能的評估數值像是總營收、淨利潤、單位時間載客量等。
#
# 再來是分析有哪些可能的方式提高業績，以車隊來說可以先提昇乘客坐車意願，亦可更進一步探討路線規劃等問題。
#
# 整個問題可以考慮成一個迴歸過程，找出各因素與業績之間的數學模型。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 影響乘客坐車意願的因素有許多，最近討論熱烈的Uber就很常提到這些因素，像是駕駛習慣、抽菸、檳榔、車內整潔度、付款方式、甚至APP的使用評價都會影響乘客是否選擇這個車隊。
#
# 抽菸、檳榔可以先對駕駛做問卷調查，付款方式大多是車隊內統一，APP使用評價可以從GOOGLE PLAY蒐集，駕駛習慣就較難定義，可以考慮從導航軟體得到的時速數據計算其變化劇烈程度來推估，或使用APP坐車後的問卷調查來蒐集資訊。
#
# 3. 蒐集而來的資料型態為何
#
# 抽菸、檳榔只要記錄成二元分類的型態即可，付款方式則可以設成目前幾個主要付款手段的二元分類，車內整潔度、駕駛習慣則以0~1的正規化浮點數來衡量，業績則要看如何定義，應使用浮點數並適當正規化。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 將車隊一部份人的資訊獨立出來當作驗證的數據，亦可以讓某些本來業績較差的駕駛，依照模型建議去改善自身條件，看業績是否可以如模型預測的增長。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(a, b):
    MSE = np.mean((a - b) ** 2)
    return MSE

def mean_absolute_error(a, b):
    MSE = np.mean(np.abs(a - b))
    return MSE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 242.517
# The Mean absolute error is 12.550
